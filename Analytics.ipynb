# %%
import pandas as pd
from plots import *
from matplotlib.pyplot import figure
import seaborn as sns
sns.set_theme()
df = pd.read_csv(
    r"C:\Users\fabia\Documents\Masterarbeit\Masterarbeit\temp\csv\expdata.csv")
df_y = get_data()
columns_renamed= {"VirtualTwinRFY" : "Virtual Twin Random Forest",
    "VirtualTwinRF_shrunk__JS_individY": "VTRF JS-Shrinker individual mean",
    "VirtualTwinRF_shrunk__JS_poolY": "VTRF JS-Shrinker overall mean",
    "VirtualTwinRF_shrunk__BAdj_individY": "VTRF Variance-Shrinker individual mean",
    "VirtualTwinRF_shrunk__BAdj_poolY": "VTRF Variance-Shrinker overall mean",
    "CausalNetY": "Causal Net",
    "CausalNet_shrunk__JS_individY": "Causal Net JS-Shrinker individual mean",
    "CausalNet_shrunk__JS_poolY": "Causal Net JS-Shrinker overall mean",
    "CausalNet_shrunk__BAdj_individY": "Causal Net Variance-Shrinker individual mean",
    "CausalNet_shrunk__BAdj_poolY": "Causal Net Variance-Shrinker overall mean",
    "CausalForestY": "Causal Forest",
    "CausalForest_shrunk__JS_individY": "Causal Forest JS-Shrinker individual mean",
    "CausalForest_shrunk__JS_poolY": "Causal Forest JS-Shrinker overall mean",
    "CausalForest_shrunk__BAdj_individY": "Causal Forest Variance-Shrinker individual mean",
    "CausalForest_shrunk__BAdj_poolY": "Causal Forest Variance-Shrinker overall mean"
    }
df_y = df_y.rename(columns_renamed, axis=1)
# Out:
# C:\Users\fabia\anaconda3\envs\MasterThesis\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
df_y.columns[::5][:-1]
# Out:
# Index(['Virtual Twin Random Forest', 'Causal Net', 'Causal Forest'], dtype='object')

# %% [markdown]
# # Tables

# %%
with open(r"C:\Users\fabia\Documents\Masterarbeit\Git\correctlyshrunk_all.joblib", "rb") as file:
    CV_Results = joblib.load(file)
print(CV_Results.overall_stats.iloc[[0,1,10,11,20,21,30,31]].round(0).astype(int))
# Out:
#                 treat_1  treat_2  treat_3  treat_4  treat_5  treat_6  overall
# VirtualTwinRFY     1935     1925     1932     1815     2135     1974     1959
# VirtualTwinRFN     9848    12328      919    27381    25300    10005    85781
# CausalNetY         1938     1963     1791     1957     1977     1796     1921
# CausalNetN        10431     5927     4008    23265    25338    17148    86117
# CausalForestY      2136     1895     2063     1788     2194     2133     1982
# CausalForestN      7721     5950       25    37917    30109     2280    84002
# AllY               1926     1930     1764     1970     1931     1871     1898
# AllN              87900    86500    87500    84800    87400    84500   518600

# %%
CV_Results.overall_stats.fillna(0).round(0).astype(int)
# Out:
#                                      treat_1  treat_2  treat_3  treat_4  \
# VirtualTwinRFY                          1935     1925     1932     1815
# VirtualTwinRFN                          9848    12328      919    27381
# VirtualTwinRF_shrunk__JS_individY       1934     1925     1953     1817
# VirtualTwinRF_shrunk__JS_individN       9837    11836      600    28004
# VirtualTwinRF_shrunk__JS_poolY          1931     1928     1851     1782
# VirtualTwinRF_shrunk__JS_poolN         60252    11564      135     8093
# VirtualTwinRF_shrunk__BAdj_individY     1948     1956        0     1850
# VirtualTwinRF_shrunk__BAdj_individN     9499    12803        0    37013
# VirtualTwinRF_shrunk__BAdj_poolY        1865     1877     1870     1762
# VirtualTwinRF_shrunk__BAdj_poolN       12811     9744     5097    14678
# CausalNetY                              1938     1963     1791     1957
# CausalNetN                             10431     5927     4008    23265
# CausalNet_shrunk__JS_individY           1924     1921     1758     1942
# CausalNet_shrunk__JS_individN           9588     6013     4420    22359
# CausalNet_shrunk__JS_poolY              1924     1940     1773     1962
# CausalNet_shrunk__JS_poolN              8275    10438    23454     5084
# CausalNet_shrunk__BAdj_individY         1924     1940     1767     1966
# CausalNet_shrunk__BAdj_individN        10586     6350     4049    23674
# CausalNet_shrunk__BAdj_poolY            1935     1951     1729     1967
# CausalNet_shrunk__BAdj_poolN            9257     4485    12597    12101
# CausalForestY                           2136     1895     2063     1788
# CausalForestN                           7721     5950       25    37917
# CausalForest_shrunk__JS_individY        2161     1959     2089     1796
# CausalForest_shrunk__JS_individN        6806     5019        4    40159
# CausalForest_shrunk__JS_poolY           1933     1931     1798     1895
# CausalForest_shrunk__JS_poolN          21160    34824      803     3486
# CausalForest_shrunk__BAdj_individY      2141     2004        0     1846
# CausalForest_shrunk__BAdj_individN      7697     4517        0    50868
# CausalForest_shrunk__BAdj_poolY         1894     1802     1905     1709
# CausalForest_shrunk__BAdj_poolN        14465     8908     2340    16361
# AllY                                    1926     1930     1764     1970
# AllN                                   87900    86500    87500    84800
#
#                                      treat_5  treat_6  overall
# VirtualTwinRFY                          2135     1974     1959
# VirtualTwinRFN                         25300    10005    85781
# VirtualTwinRF_shrunk__JS_individY       2142     1976     1963
# VirtualTwinRF_shrunk__JS_individN      26111     9375    85763
# VirtualTwinRF_shrunk__JS_poolY          2154     1921     1928
# VirtualTwinRF_shrunk__JS_poolN          4340     2322    86706
# VirtualTwinRF_shrunk__BAdj_individY     2133     2000     1962
# VirtualTwinRF_shrunk__BAdj_individN    24775     1909    85999
# VirtualTwinRF_shrunk__BAdj_poolY        2120     1942     1938
# VirtualTwinRF_shrunk__BAdj_poolN       24115    18509    84954
# CausalNetY                              1977     1796     1921
# CausalNetN                             25338    17148    86117
# CausalNet_shrunk__JS_individY           1969     1852     1918
# CausalNet_shrunk__JS_individN          25267    18282    85929
# CausalNet_shrunk__JS_poolY              1930     1871     1864
# CausalNet_shrunk__JS_poolN              2037    36913    86201
# CausalNet_shrunk__BAdj_individY         1949     1843     1922
# CausalNet_shrunk__BAdj_individN        25913    15441    86013
# CausalNet_shrunk__BAdj_poolY            2002     1797     1889
# CausalNet_shrunk__BAdj_poolN           22722    23962    85124
# CausalForestY                           2194     2133     1982
# CausalForestN                          30109     2280    84002
# CausalForest_shrunk__JS_individY        2197     2126     1988
# CausalForest_shrunk__JS_individN       31452      696    84136
# CausalForest_shrunk__JS_poolY              0     1870     1910
# CausalForest_shrunk__JS_poolN              0    25997    86270
# CausalForest_shrunk__BAdj_individY      2222     2073     1975
# CausalForest_shrunk__BAdj_individN     20661      149    83892
# CausalForest_shrunk__BAdj_poolY         2158     1919     1939
# CausalForest_shrunk__BAdj_poolN        27492    13984    83550
# AllY                                    1931     1871     1898
# AllN                                   87400    84500   518600

# %%
with open(r"C:\Users\fabia\Documents\Masterarbeit\Git\correctlyshrunk_all.joblib", "rb") as file:
    CV_Results = joblib.load(file)
print(CV_Results.overall_stats.fillna(0).round(0).astype(int).to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# {} &  treat\_1 &  treat\_2 &  treat\_3 &  treat\_4 &  treat\_5 &  treat\_6 &  overall \\
# \midrule
# VirtualTwinRFY                      &     1935 &     1925 &     1932 &     1815 &     2135 &     1974 &     1959 \\
# VirtualTwinRFN                      &     9848 &    12328 &      919 &    27381 &    25300 &    10005 &    85781 \\
# VirtualTwinRF\_shrunk\_\_JS\_individY   &     1934 &     1925 &     1953 &     1817 &     2142 &     1976 &     1963 \\
# VirtualTwinRF\_shrunk\_\_JS\_individN   &     9837 &    11836 &      600 &    28004 &    26111 &     9375 &    85763 \\
# VirtualTwinRF\_shrunk\_\_JS\_poolY      &     1931 &     1928 &     1851 &     1782 &     2154 &     1921 &     1928 \\
# VirtualTwinRF\_shrunk\_\_JS\_poolN      &    60252 &    11564 &      135 &     8093 &     4340 &     2322 &    86706 \\
# VirtualTwinRF\_shrunk\_\_BAdj\_individY &     1948 &     1956 &        0 &     1850 &     2133 &     2000 &     1962 \\
# VirtualTwinRF\_shrunk\_\_BAdj\_individN &     9499 &    12803 &        0 &    37013 &    24775 &     1909 &    85999 \\
# VirtualTwinRF\_shrunk\_\_BAdj\_poolY    &     1865 &     1877 &     1870 &     1762 &     2120 &     1942 &     1938 \\
# VirtualTwinRF\_shrunk\_\_BAdj\_poolN    &    12811 &     9744 &     5097 &    14678 &    24115 &    18509 &    84954 \\
# CausalNetY                          &     1938 &     1963 &     1791 &     1957 &     1977 &     1796 &     1921 \\
# CausalNetN                          &    10431 &     5927 &     4008 &    23265 &    25338 &    17148 &    86117 \\
# CausalNet\_shrunk\_\_JS\_individY       &     1924 &     1921 &     1758 &     1942 &     1969 &     1852 &     1918 \\
# CausalNet\_shrunk\_\_JS\_individN       &     9588 &     6013 &     4420 &    22359 &    25267 &    18282 &    85929 \\
# CausalNet\_shrunk\_\_JS\_poolY          &     1924 &     1940 &     1773 &     1962 &     1930 &     1871 &     1864 \\
# CausalNet\_shrunk\_\_JS\_poolN          &     8275 &    10438 &    23454 &     5084 &     2037 &    36913 &    86201 \\
# CausalNet\_shrunk\_\_BAdj\_individY     &     1924 &     1940 &     1767 &     1966 &     1949 &     1843 &     1922 \\
# CausalNet\_shrunk\_\_BAdj\_individN     &    10586 &     6350 &     4049 &    23674 &    25913 &    15441 &    86013 \\
# CausalNet\_shrunk\_\_BAdj\_poolY        &     1935 &     1951 &     1729 &     1967 &     2002 &     1797 &     1889 \\
# CausalNet\_shrunk\_\_BAdj\_poolN        &     9257 &     4485 &    12597 &    12101 &    22722 &    23962 &    85124 \\
# CausalForestY                       &     2136 &     1895 &     2063 &     1788 &     2194 &     2133 &     1982 \\
# CausalForestN                       &     7721 &     5950 &       25 &    37917 &    30109 &     2280 &    84002 \\
# CausalForest\_shrunk\_\_JS\_individY    &     2161 &     1959 &     2089 &     1796 &     2197 &     2126 &     1988 \\
# CausalForest\_shrunk\_\_JS\_individN    &     6806 &     5019 &        4 &    40159 &    31452 &      696 &    84136 \\
# CausalForest\_shrunk\_\_JS\_poolY       &     1933 &     1931 &     1798 &     1895 &        0 &     1870 &     1910 \\
# CausalForest\_shrunk\_\_JS\_poolN       &    21160 &    34824 &      803 &     3486 &        0 &    25997 &    86270 \\
# CausalForest\_shrunk\_\_BAdj\_individY  &     2141 &     2004 &        0 &     1846 &     2222 &     2073 &     1975 \\
# CausalForest\_shrunk\_\_BAdj\_individN  &     7697 &     4517 &        0 &    50868 &    20661 &      149 &    83892 \\
# CausalForest\_shrunk\_\_BAdj\_poolY     &     1894 &     1802 &     1905 &     1709 &     2158 &     1919 &     1939 \\
# CausalForest\_shrunk\_\_BAdj\_poolN     &    14465 &     8908 &     2340 &    16361 &    27492 &    13984 &    83550 \\
# AllY                                &     1926 &     1930 &     1764 &     1970 &     1931 &     1871 &     1898 \\
# AllN                                &    87900 &    86500 &    87500 &    84800 &    87400 &    84500 &   518600 \\
# \bottomrule
# \end{tabular}
# In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.

# %%
print(CV_Results.overall_stats.iloc[[0,1,10,11,20,21,30,31]].round(0).astype(int).to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# {} &  treat\_1 &  treat\_2 &  treat\_3 &  treat\_4 &  treat\_5 &  treat\_6 &  overall \\
# \midrule
# VirtualTwinRFY &     1935 &     1925 &     1932 &     1815 &     2135 &     1974 &     1959 \\
# VirtualTwinRFN &     9848 &    12328 &      919 &    27381 &    25300 &    10005 &    85781 \\
# CausalNetY     &     1938 &     1963 &     1791 &     1957 &     1977 &     1796 &     1921 \\
# CausalNetN     &    10431 &     5927 &     4008 &    23265 &    25338 &    17148 &    86117 \\
# CausalForestY  &     2136 &     1895 &     2063 &     1788 &     2194 &     2133 &     1982 \\
# CausalForestN  &     7721 &     5950 &       25 &    37917 &    30109 &     2280 &    84002 \\
# AllY           &     1926 &     1930 &     1764 &     1970 &     1931 &     1871 &     1898 \\
# AllN           &    87900 &    86500 &    87500 &    84800 &    87400 &    84500 &   518600 \\
# \bottomrule
# \end{tabular}
# In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.

# %% [markdown]
# # Misra Matching Plots

# %% [markdown]
# ## Main Plots

# %%
I, J = (2,2)
fig, ax =plt.subplots(I,J, figsize=(15, 13))
i = 0
j = 0
for column in df_y.columns[::5][:-1]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[1][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## VTRF Shrunk

# %%
I, J = (3,2)
fig, ax =plt.subplots(I,J, figsize=(15, 20))
i = 0
j = 0
for column in df_y.columns[:5]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[2][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Causal Net Shrunk

# %%
I, J = (3,2)
fig, ax =plt.subplots(I,J, figsize=(15, 20))
i = 0
j = 0
for column in df_y.columns[5:10]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[2][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Causal Forest Shrunk

# %%
I, J = (3,2)
fig, ax =plt.subplots(I,J, figsize=(15, 20))
i = 0
j = 0
for column in df_y.columns[10:15]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[2][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %%
sns.distplot(df.age, axlabel="Age")
plt.axvline(df.age.mean(),color="black")
plt.text(df.age.mean()+.5,.01,'Mean',rotation=90)
plt.axvline(df.age.median(), color="blue")
plt.text(df.age.median()-3,.01,'Median',rotation=90)
# Out:
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# Text(33.0, 0.01, 'Median')

# %%
from numpy import median
fig, ax =plt.subplots(1,2, figsize=(15, 5))
sns.pointplot(y="buttonpresses", x="treat", data=df, ax=ax[0])
ax[0].axhline(df.buttonpresses.mean(),color="black", linestyle='--')
ax[0].text(0,df.buttonpresses.mean()-50,'Overall mean')
ax[0].set_xlabel("treatment")
ax[0].set_title('Mean')
ax[0].set(ylim=(1400, 2200))


sns.pointplot(y="buttonpresses", x="treat", data=df, estimator=median, ax=ax[1])
ax[1].axhline(df.buttonpresses.median(),color="black", linestyle='--')
ax[1].text(0,df.buttonpresses.median()-50,'Overall median')
ax[1].set_xlabel("treatment")
ax[1].set_title('Median')
ax[1].set(ylim=(1400, 2200))
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
df.buttonpresses.median()
# Out:
# 2012.0

# %%
sns.set_theme()
sns.displot(x="buttonpresses", hue="treat", kind="kde", data=df, palette="Set1")

# %% [markdown]
# ## Wilcoxon Rank Sum Test

# %%
from scipy.stats import ranksums
for treatment in range(1,7):
    print("treatment ",treatment)
    print(ranksums(df.buttonpresses[df.treat==treatment], df.buttonpresses[df.treat==7], alternative='greater' ))
# Out:
# treatment  1
# RanksumsResult(statistic=10.804961828447041, pvalue=1.6304630554446328e-27)
# treatment  2
# RanksumsResult(statistic=11.291955882297154, pvalue=7.190029897962477e-30)
# treatment  3
# RanksumsResult(statistic=6.633164793738577, pvalue=1.6428231309114618e-11)
# treatment  4
# RanksumsResult(statistic=12.59486847857614, pvalue=1.1266760991976089e-36)
# treatment  5
# RanksumsResult(statistic=10.76038127226417, pvalue=2.647531716967946e-27)
# treatment  6
# RanksumsResult(statistic=9.178741587158857, pvalue=2.1807923808438725e-20)

# %%
for treatment1 in range(1,7):
    print("> Treatment ", treatment1)
    for treatment in range(1,7):
        print("treatment ",treatment)
        print(ranksums(df.buttonpresses[df.treat==treatment], df.buttonpresses[df.treat==treatment1], alternative='greater' ))
    print("\n")
# Out:
# > Treatment  1
# treatment  1
# RanksumsResult(statistic=0.0, pvalue=0.5)
# treatment  2
# RanksumsResult(statistic=0.13689957040945597, pvalue=0.44555508920165476)
# treatment  3
# RanksumsResult(statistic=-4.192158641044594, pvalue=0.999986184366966)
# treatment  4
# RanksumsResult(statistic=1.2895824128688416, pvalue=0.09859784264125981)
# treatment  5
# RanksumsResult(statistic=0.0863469036673526, pvalue=0.4655953269709259)
# treatment  6
# RanksumsResult(statistic=-1.67681103823023, pvalue=0.9532102807201464)
#
#
# > Treatment  2
# treatment  1
# RanksumsResult(statistic=-0.13689957040945597, pvalue=0.5544449107983452)
# treatment  2
# RanksumsResult(statistic=0.0, pvalue=0.5)
# treatment  3
# RanksumsResult(statistic=-4.397546868546451, pvalue=0.9999945259375816)
# treatment  4
# RanksumsResult(statistic=1.2491481078771691, pvalue=0.10580545383959994)
# treatment  5
# RanksumsResult(statistic=0.005969421510050947, pvalue=0.49761855951348366)
# treatment  6
# RanksumsResult(statistic=-1.9304107466348073, pvalue=0.9732220177884878)
#
#
# > Treatment  3
# treatment  1
# RanksumsResult(statistic=4.192158641044594, pvalue=1.3815633034021938e-05)
# treatment  2
# RanksumsResult(statistic=4.397546868546451, pvalue=5.474062418335362e-06)
# treatment  3
# RanksumsResult(statistic=0.0, pvalue=0.5)
# treatment  4
# RanksumsResult(statistic=5.622213073328169, pvalue=9.426326509756545e-09)
# treatment  5
# RanksumsResult(statistic=4.268843306806821, pvalue=9.82446164574108e-06)
# treatment  6
# RanksumsResult(statistic=2.5048290059630616, pvalue=0.00612553026887241)
#
#
# > Treatment  4
# treatment  1
# RanksumsResult(statistic=-1.2895824128688416, pvalue=0.9014021573587402)
# treatment  2
# RanksumsResult(statistic=-1.2491481078771691, pvalue=0.8941945461604001)
# treatment  3
# RanksumsResult(statistic=-5.622213073328169, pvalue=0.9999999905736735)
# treatment  4
# RanksumsResult(statistic=0.0, pvalue=0.5)
# treatment  5
# RanksumsResult(statistic=-1.101894973233396, pvalue=0.8647463328902634)
# treatment  6
# RanksumsResult(statistic=-3.113580190291862, pvalue=0.9990758386261026)
#
#
# > Treatment  5
# treatment  1
# RanksumsResult(statistic=-0.0863469036673526, pvalue=0.5344046730290741)
# treatment  2
# RanksumsResult(statistic=-0.005969421510050947, pvalue=0.5023814404865163)
# treatment  3
# RanksumsResult(statistic=-4.268843306806821, pvalue=0.9999901755383542)
# treatment  4
# RanksumsResult(statistic=1.101894973233396, pvalue=0.13525366710973663)
# treatment  5
# RanksumsResult(statistic=0.0, pvalue=0.5)
# treatment  6
# RanksumsResult(statistic=-1.6696581742233234, pvalue=0.9525064932682981)
#
#
# > Treatment  6
# treatment  1
# RanksumsResult(statistic=1.67681103823023, pvalue=0.046789719279853655)
# treatment  2
# RanksumsResult(statistic=1.9304107466348073, pvalue=0.026777982211512213)
# treatment  3
# RanksumsResult(statistic=-2.5048290059630616, pvalue=0.9938744697311276)
# treatment  4
# RanksumsResult(statistic=3.113580190291862, pvalue=0.0009241613738974091)
# treatment  5
# RanksumsResult(statistic=1.6696581742233234, pvalue=0.0474935067317019)
# treatment  6
# RanksumsResult(statistic=0.0, pvalue=0.5)

# %%
df_y.columns[::5][:-1]
# Out:
# Index(['Virtual Twin Random Forest', 'Causal Net', 'Causal Forest'], dtype='object')

# %% [markdown]
# # Tables

# %%
with open(r"C:\Users\fabia\Documents\Masterarbeit\Git\correctlyshrunk_part.joblib", "rb") as file:
    CV_Results = joblib.load(file)
print(CV_Results.overall_stats.iloc[[0,1,10,11,20,21,30,31]].round(0).astype(int))
# Out:
#                 treat_1  treat_2  treat_4  treat_5  overall
# VirtualTwinRFY     1971     1954     1831     2136     1970
# VirtualTwinRFN    12102    15824    30825    27436    86187
# CausalNetY         1910     1932     1948     1962     1945
# CausalNetN        14266     9394    29754    32824    86238
# CausalForestY      2145     1926     1786     2185     1980
# CausalForestN      8606     6443    38062    30855    83966
# AllY               1926     1930     1970     1931     1939
# AllN              87900    86500    84800    87400   346600

# %%
print(CV_Results.overall_stats.iloc[[0,1,10,11,20,21,30,31]].round(0).astype(int).to_latex())
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  treat\_1 &  treat\_2 &  treat\_4 &  treat\_5 &  overall \\
# \midrule
# VirtualTwinRFY &     1971 &     1954 &     1831 &     2136 &     1970 \\
# VirtualTwinRFN &    12102 &    15824 &    30825 &    27436 &    86187 \\
# CausalNetY     &     1910 &     1932 &     1948 &     1962 &     1945 \\
# CausalNetN     &    14266 &     9394 &    29754 &    32824 &    86238 \\
# CausalForestY  &     2145 &     1926 &     1786 &     2185 &     1980 \\
# CausalForestN  &     8606 &     6443 &    38062 &    30855 &    83966 \\
# AllY           &     1926 &     1930 &     1970 &     1931 &     1939 \\
# AllN           &    87900 &    86500 &    84800 &    87400 &   346600 \\
# \bottomrule
# \end{tabular}
# In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.

# %% [markdown]
# # Misra Matching Plots

# %%
df_y = get_data(full_data=False)
columns_renamed= {"VirtualTwinRFY" : "Virtual Twin Random Forest",
    "VirtualTwinRF_shrunk__JS_individY": "VTRF JS-Shrinker individual mean",
    "VirtualTwinRF_shrunk__JS_poolY": "VTRF JS-Shrinker overall mean",
    "VirtualTwinRF_shrunk__BAdj_individY": "VTRF Variance-Shrinker individual mean",
    "VirtualTwinRF_shrunk__BAdj_poolY": "VTRF Variance-Shrinker overall mean",
    "CausalNetY": "Causal Net",
    "CausalNet_shrunk__JS_individY": "Causal Net JS-Shrinker individual mean",
    "CausalNet_shrunk__JS_poolY": "Causal Net JS-Shrinker overall mean",
    "CausalNet_shrunk__BAdj_individY": "Causal Net Variance-Shrinker individual mean",
    "CausalNet_shrunk__BAdj_poolY": "Causal Net Variance-Shrinker overall mean",
    "CausalForestY": "Causal Forest",
    "CausalForest_shrunk__JS_individY": "Causal Forest JS-Shrinker individual mean",
    "CausalForest_shrunk__JS_poolY": "Causal Forest JS-Shrinker overall mean",
    "CausalForest_shrunk__BAdj_individY": "Causal Forest Variance-Shrinker individual mean",
    "CausalForest_shrunk__BAdj_poolY": "Causal Forest Variance-Shrinker overall mean"
    }
df_y = df_y.rename(columns_renamed, axis=1)

# %% [markdown]
# ## Main Plots

# %%
I, J = (2,2)
fig, ax =plt.subplots(I,J, figsize=(15, 13))
i = 0
j = 0
for column in df_y.columns[::5][:-1]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[1][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## VTRF Shrunk

# %%
I, J = (3,2)
fig, ax =plt.subplots(I,J, figsize=(15, 20))
i = 0
j = 0
for column in df_y.columns[:5]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[2][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Causal Net Shrunk

# %%
I, J = (3,2)
fig, ax =plt.subplots(I,J, figsize=(15, 20))
i = 0
j = 0
for column in df_y.columns[5:10]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[2][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Causal Forest Shrunk

# %%
I, J = (3,2)
fig, ax =plt.subplots(I,J, figsize=(15, 20))
i = 0
j = 0
for column in df_y.columns[10:15]:
    makeplot(df_y[column], ax=ax[i][j])
    if j<J-1:
        j+=1
    else:
        i+=1
        j=0
fig.delaxes(ax[2][1])
fig.show()
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
x
